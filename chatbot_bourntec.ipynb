# %%
import random
import json
import pickle
import numpy as np
import nltk

from nltk.stem import WordNetLemmatizer
from keras.models import load_model

lemmatizer = WordNetLemmatizer()
intents = json.loads(open('intents.json').read())

words = pickle.load(open('words.pkl', 'rb'))
classes = pickle.load(open('classes.pkl', 'rb'))
model = load_model('bourntec_chatbot_model.h5')


def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word) for word in sentence_words]
    return sentence_words

def bag_of_words (sentence):
    sentence_words = clean_up_sentence(sentence)
    bag = [0] * len(words)
    for w in sentence_words:
        for i, word in enumerate(words):
            if word == w:
                bag[i] = 1
    return np.array(bag)

def predict_class (sentence):
    bow = bag_of_words (sentence)
    res = model.predict(np.array([bow]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]

    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({'intent': classes [r[0]], 'probability': str(r[1])})
    return return_list

def get_response(intents_list, intents_json):
    tag = intents_list[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if i['tag'] == tag:
            result = random.choice (i['responses'])
            break
    return result

print("Hi I'm KASS ")

while True:
    message = input("")
    ints = predict_class (message)
    res = get_response (ints, intents)
    print (res)
# Out:
# Hi I'm KASS
# bye
# 1/1 [==============================] - 2s 2s/step
# Goodbye!
# india location
# 1/1 [==============================] - 0s 63ms/step
# Bourntec's India office is situated at 5 locations.
# 1.Sundarpada, Bhubaneswar, Odisha, India. -> view the location on Google Maps https://maps.app.goo.gl/yNC2AsDwzSfrgmfD8
# 2.OCAC Building,Acharya Vihar,Bhubaneswar, Odisha, India -> view the location on Google Maps https://maps.app.goo.gl/9S2SHxF7faHupn928
# 3.Hitech City, Madhapur, Hyderabad, India. -> https://maps.app.goo.gl/42KTDfAzW9WQbknh8
# 4.Kakkanad, Kochi, Kerala, India. -> view the location on Google Maps https://maps.app.goo.gl/LmDxVkfZ8viGojcs6
# 5.Bourntec Solutions Pvt Ltd,Noel Focus, 4th Floor(4B, 4C, 4D),Chittethukara,CSEZ P.O, Kochi, Kerala,  India. -> https://maps.app.goo.gl/84S3vvCAEvFBZRCZA
# hi
# 1/1 [==============================] - 0s 63ms/step
# Bourntec's India office is situated at 5 locations.
# 1.Sundarpada, Bhubaneswar, Odisha, India. -> view the location on Google Maps https://maps.app.goo.gl/yNC2AsDwzSfrgmfD8
# 2.OCAC Building,Acharya Vihar,Bhubaneswar, Odisha, India -> view the location on Google Maps https://maps.app.goo.gl/9S2SHxF7faHupn928
# 3.Hitech City, Madhapur, Hyderabad, India. -> https://maps.app.goo.gl/42KTDfAzW9WQbknh8
# 4.Kakkanad, Kochi, Kerala, India. -> view the location on Google Maps https://maps.app.goo.gl/LmDxVkfZ8viGojcs6
# 5.Bourntec Solutions Pvt Ltd,Noel Focus, 4th Floor(4B, 4C, 4D),Chittethukara,CSEZ P.O, Kochi, Kerala,  India. -> https://maps.app.goo.gl/84S3vvCAEvFBZRCZA
#
# 1/1 [==============================] - 0s 78ms/step
# Bourntec's India office is situated at 5 locations.
# 1.Sundarpada, Bhubaneswar, Odisha, India. -> view the location on Google Maps https://maps.app.goo.gl/yNC2AsDwzSfrgmfD8
# 2.OCAC Building,Acharya Vihar,Bhubaneswar, Odisha, India -> view the location on Google Maps https://maps.app.goo.gl/9S2SHxF7faHupn928
# 3.Hitech City, Madhapur, Hyderabad, India. -> https://maps.app.goo.gl/42KTDfAzW9WQbknh8
# 4.Kakkanad, Kochi, Kerala, India. -> view the location on Google Maps https://maps.app.goo.gl/LmDxVkfZ8viGojcs6
# 5.Bourntec Solutions Pvt Ltd,Noel Focus, 4th Floor(4B, 4C, 4D),Chittethukara,CSEZ P.O, Kochi, Kerala,  India. -> https://maps.app.goo.gl/84S3vvCAEvFBZRCZA
